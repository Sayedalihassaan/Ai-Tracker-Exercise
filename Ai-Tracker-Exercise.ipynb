# %%
import cv2
import mediapipe as mp
import numpy as np
from ultralytics import YOLO
import cvzone
import os
from playsound import playsound 

path = r"D:\Computer Vision\Ai-Tracker-Exercise"
os.chdir(path)
from tracker import Tracker

mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils
pose = mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5)

# Model
model = YOLO("yolov8s.pt")

# Data
with open(r"coco.txt", "r") as df:
    classes = df.read().split("\n")



cap = cv2.VideoCapture(r"pushup.mp4")

counter = 0
stage = None

def calculate_angle(a, b, c):
    a, b, c = np.array(a), np.array(b), np.array(c)
    
    angle_ab = np.arctan2(a[1] - b[1], a[0] - b[0])
    angle_bc = np.arctan2(c[1] - b[1], c[0] - b[0])
    
    angle = np.abs(angle_ab - angle_bc)
    angle = np.degrees(angle)
    
    if angle > 180:
        angle = 360 - angle
    return angle

# Initialize tracker
tracker = Tracker()


alarm_path = r"D:\Computer Vision\Ai-Tracker-Exercise\assets_alarm.mp3"


while True:
    ret, frame = cap.read()
    if not ret:
        print("Error loading video.")
        break

    frame = cv2.resize(frame, (1100, 700))
    h, w, _ = frame.shape

    
    results = model(frame)
    result = pose.process(frame)

    
    if result.pose_landmarks:
        mp_drawing.draw_landmarks(
            frame, result.pose_landmarks, mp_pose.POSE_CONNECTIONS,
            mp_drawing.DrawingSpec(color=(255, 0, 0), thickness=2, circle_radius=2),
            mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=2, circle_radius=2)
        )
        
        landmarks = result.pose_landmarks.landmark
        
        L_shoulder = [landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x * w,
                      landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y * h]
        L_elbow = [landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].x * w,
                   landmarks[mp_pose.PoseLandmark.LEFT_ELBOW.value].y * h]
        L_wrist = [landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].x * w,
                   landmarks[mp_pose.PoseLandmark.LEFT_WRIST.value].y * h]
        
        R_shoulder = [landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x * w,
                      landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y * h]
        R_elbow = [landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].x * w,
                   landmarks[mp_pose.PoseLandmark.RIGHT_ELBOW.value].y * h]
        R_wrist = [landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].x * w,
                   landmarks[mp_pose.PoseLandmark.RIGHT_WRIST.value].y * h]

        
        l_angle = calculate_angle(L_shoulder, L_elbow, L_wrist)
        r_angle = calculate_angle(R_shoulder, R_elbow, R_wrist)

        cv2.putText(frame, f"left_angle: {str(int(l_angle))}", tuple(np.multiply(L_elbow, [1, 1]).astype(int)),
                    cv2.FONT_HERSHEY_PLAIN, 2, (255, 0, 0), 2)
        
        cv2.putText(frame, f"right_angle: {str(int(r_angle))}", tuple(np.multiply(R_elbow, [1, 1]).astype(int)),
                    cv2.FONT_HERSHEY_PLAIN, 2, (0, 255, 255), 3)
        
        
        
        if l_angle > 160 and r_angle > 160:
            stage = "UP"
        if (l_angle < 70 and stage == "UP") and (r_angle < 70 and stage == "UP"):
            stage = "Down"
            counter += 1
            print(counter)
            
            playsound(alarm_path)
               
                

    cvzone.putTextRect(frame, f"Counter: {counter}", (10, 60), scale=3, thickness=2, colorR=(255, 255, 0), colorT=(0, 0, 0))
    cvzone.putTextRect(frame, f"State: {stage}", (10, 120), scale=3, thickness=2, colorR=(255, 0, 255), colorT=(0, 0, 0))

    
    lis = []
    for res in results:
        for box in res.boxes:
            x1, y1, x2, y2 = map(int, box.xyxy[0])
            name = classes[int(box.cls[0])]
            if "person" in name and box.conf[0] > 0.5:
                lis.append([x1, y1, x2, y2])

    bbox_id = tracker.update(lis)
    for bb in bbox_id:
        x1, y1, x2, y2, idd = bb
        ww = x2 - x1
        hh = y2 - y1
        
        cvzone.putTextRect(frame, f"Person ID: {idd}", (x1+140, y1-10), scale=1, thickness=1, colorR=(0, 255, 0), colorT=(0, 0, 0))
        cvzone.cornerRect(frame, (x1, y1, ww, hh), l=15, t=15, rt=2, colorR=(0, 0, 0), colorC=(0, 255, 0))
        
    cv2.imshow("Frame", frame)

    if cv2.waitKey(1) == ord("q"):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 416x640 1 person, 352.1ms
# Speed: 8.0ms preprocess, 352.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 488.1ms
# Speed: 8.0ms preprocess, 488.1ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 300.7ms
# Speed: 4.0ms preprocess, 300.7ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 281.8ms
# Speed: 4.0ms preprocess, 281.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 270.8ms
# Speed: 4.0ms preprocess, 270.8ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 266.3ms
# Speed: 6.0ms preprocess, 266.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 268.8ms
# Speed: 4.0ms preprocess, 268.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 253.8ms
# Speed: 5.0ms preprocess, 253.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 256.3ms
# Speed: 8.0ms preprocess, 256.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 257.8ms
# Speed: 3.9ms preprocess, 257.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 254.3ms
# Speed: 30.9ms preprocess, 254.3ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 265.8ms
# Speed: 4.0ms preprocess, 265.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 256.3ms
# Speed: 5.0ms preprocess, 256.3ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 258.8ms
# Speed: 5.0ms preprocess, 258.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 247.4ms
# Speed: 4.0ms preprocess, 247.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 266.8ms
# Speed: 4.0ms preprocess, 266.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 235.9ms
# Speed: 4.0ms preprocess, 235.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 245.4ms
# Speed: 3.0ms preprocess, 245.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 221.9ms
# Speed: 4.0ms preprocess, 221.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 230.4ms
# Speed: 4.0ms preprocess, 230.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 224.9ms
# Speed: 3.0ms preprocess, 224.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 241.4ms
# Speed: 3.0ms preprocess, 241.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 234.9ms
# Speed: 4.0ms preprocess, 234.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 229.9ms
# Speed: 3.0ms preprocess, 229.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 232.9ms
# Speed: 4.0ms preprocess, 232.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 241.4ms
# Speed: 4.0ms preprocess, 241.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 254.8ms
# Speed: 4.0ms preprocess, 254.8ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 247.8ms
# Speed: 4.0ms preprocess, 247.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 250.4ms
# Speed: 4.0ms preprocess, 250.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 234.9ms
# Speed: 3.0ms preprocess, 234.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 skateboard, 240.4ms
# Speed: 4.0ms preprocess, 240.4ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 skateboard, 272.8ms
# Speed: 3.0ms preprocess, 272.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 233.9ms
# Speed: 3.0ms preprocess, 233.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 232.9ms
# Speed: 4.0ms preprocess, 232.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 232.9ms
# Speed: 4.0ms preprocess, 232.9ms inference, 3.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 240.9ms
# Speed: 3.0ms preprocess, 240.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 229.4ms
# Speed: 4.0ms preprocess, 229.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 226.9ms
# Speed: 4.0ms preprocess, 226.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 241.9ms
# Speed: 4.0ms preprocess, 241.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 238.4ms
# Speed: 4.0ms preprocess, 238.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 250.8ms
# Speed: 3.0ms preprocess, 250.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 240.9ms
# Speed: 4.0ms preprocess, 240.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 233.4ms
# Speed: 3.0ms preprocess, 233.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 238.9ms
# Speed: 4.0ms preprocess, 238.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 230.9ms
# Speed: 4.0ms preprocess, 230.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# 1
#
# 0: 416x640 1 person, 236.9ms
# Speed: 4.0ms preprocess, 236.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 235.9ms
# Speed: 4.0ms preprocess, 235.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 251.3ms
# Speed: 4.0ms preprocess, 251.3ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 231.9ms
# Speed: 6.0ms preprocess, 231.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 241.4ms
# Speed: 4.0ms preprocess, 241.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 240.9ms
# Speed: 4.0ms preprocess, 240.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 226.4ms
# Speed: 3.0ms preprocess, 226.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 241.9ms
# Speed: 4.0ms preprocess, 241.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 228.9ms
# Speed: 3.0ms preprocess, 228.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 235.9ms
# Speed: 3.0ms preprocess, 235.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 234.9ms
# Speed: 4.0ms preprocess, 234.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 238.4ms
# Speed: 4.0ms preprocess, 238.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 228.9ms
# Speed: 5.0ms preprocess, 228.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 227.9ms
# Speed: 4.0ms preprocess, 227.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 235.9ms
# Speed: 3.0ms preprocess, 235.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 245.8ms
# Speed: 3.0ms preprocess, 245.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 251.3ms
# Speed: 3.0ms preprocess, 251.3ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 239.9ms
# Speed: 4.0ms preprocess, 239.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 244.9ms
# Speed: 3.0ms preprocess, 244.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 235.4ms
# Speed: 4.0ms preprocess, 235.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 233.9ms
# Speed: 3.0ms preprocess, 233.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 236.9ms
# Speed: 3.5ms preprocess, 236.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 233.9ms
# Speed: 4.0ms preprocess, 233.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 240.9ms
# Speed: 4.0ms preprocess, 240.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 234.4ms
# Speed: 3.0ms preprocess, 234.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 237.9ms
# Speed: 4.0ms preprocess, 237.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 239.9ms
# Speed: 4.0ms preprocess, 239.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 269.3ms
# Speed: 3.0ms preprocess, 269.3ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 236.9ms
# Speed: 5.0ms preprocess, 236.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 245.9ms
# Speed: 3.0ms preprocess, 245.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 247.4ms
# Speed: 4.0ms preprocess, 247.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 247.9ms
# Speed: 3.0ms preprocess, 247.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 226.9ms
# Speed: 4.0ms preprocess, 226.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 232.4ms
# Speed: 3.0ms preprocess, 232.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 235.9ms
# Speed: 3.0ms preprocess, 235.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 237.9ms
# Speed: 5.0ms preprocess, 237.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 235.9ms
# Speed: 3.0ms preprocess, 235.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 231.4ms
# Speed: 4.0ms preprocess, 231.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 238.9ms
# Speed: 3.0ms preprocess, 238.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 229.9ms
# Speed: 3.0ms preprocess, 229.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 229.9ms
# Speed: 5.0ms preprocess, 229.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 244.9ms
# Speed: 4.0ms preprocess, 244.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 251.8ms
# Speed: 4.0ms preprocess, 251.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 257.4ms
# Speed: 3.0ms preprocess, 257.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 246.9ms
# Speed: 4.0ms preprocess, 246.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 skateboard, 235.9ms
# Speed: 3.0ms preprocess, 235.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 236.9ms
# Speed: 4.0ms preprocess, 236.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 268.8ms
# Speed: 5.0ms preprocess, 268.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 276.8ms
# Speed: 4.0ms preprocess, 276.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 276.8ms
# Speed: 5.0ms preprocess, 276.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 282.3ms
# Speed: 4.0ms preprocess, 282.3ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 256.3ms
# Speed: 4.0ms preprocess, 256.3ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 266.3ms
# Speed: 4.0ms preprocess, 266.3ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 267.8ms
# Speed: 3.0ms preprocess, 267.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 276.8ms
# Speed: 3.0ms preprocess, 276.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 275.3ms
# Speed: 4.0ms preprocess, 275.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 265.8ms
# Speed: 4.0ms preprocess, 265.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 270.3ms
# Speed: 4.0ms preprocess, 270.3ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 257.3ms
# Speed: 4.0ms preprocess, 257.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 255.8ms
# Speed: 4.0ms preprocess, 255.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 253.8ms
# Speed: 4.0ms preprocess, 253.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 257.3ms
# Speed: 5.0ms preprocess, 257.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 264.3ms
# Speed: 3.0ms preprocess, 264.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 260.8ms
# Speed: 3.0ms preprocess, 260.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 274.8ms
# Speed: 4.0ms preprocess, 274.8ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 268.8ms
# Speed: 3.0ms preprocess, 268.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 268.4ms
# Speed: 5.0ms preprocess, 268.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 281.8ms
# Speed: 3.0ms preprocess, 281.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 259.8ms
# Speed: 4.0ms preprocess, 259.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 250.8ms
# Speed: 4.0ms preprocess, 250.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 254.4ms
# Speed: 4.0ms preprocess, 254.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 258.8ms
# Speed: 4.0ms preprocess, 258.8ms inference, 4.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 258.8ms
# Speed: 3.0ms preprocess, 258.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 253.8ms
# Speed: 3.0ms preprocess, 253.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 251.4ms
# Speed: 3.0ms preprocess, 251.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 248.8ms
# Speed: 5.0ms preprocess, 248.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 264.8ms
# Speed: 4.0ms preprocess, 264.8ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 266.3ms
# Speed: 3.0ms preprocess, 266.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# 2
#
# 0: 416x640 1 person, 231.4ms
# Speed: 3.0ms preprocess, 231.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 243.4ms
# Speed: 4.0ms preprocess, 243.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 241.4ms
# Speed: 5.0ms preprocess, 241.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 235.4ms
# Speed: 4.0ms preprocess, 235.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 238.4ms
# Speed: 3.0ms preprocess, 238.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 249.3ms
# Speed: 3.0ms preprocess, 249.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 267.8ms
# Speed: 3.0ms preprocess, 267.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 263.3ms
# Speed: 4.0ms preprocess, 263.3ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 255.9ms
# Speed: 6.0ms preprocess, 255.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 255.0ms
# Speed: 6.0ms preprocess, 255.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 242.9ms
# Speed: 4.0ms preprocess, 242.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 248.9ms
# Speed: 5.0ms preprocess, 248.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 239.0ms
# Speed: 4.0ms preprocess, 239.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 243.5ms
# Speed: 4.0ms preprocess, 243.5ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 238.9ms
# Speed: 3.0ms preprocess, 238.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 241.5ms
# Speed: 4.5ms preprocess, 241.5ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 235.0ms
# Speed: 4.0ms preprocess, 235.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 243.1ms
# Speed: 4.0ms preprocess, 243.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 242.0ms
# Speed: 4.0ms preprocess, 242.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 242.4ms
# Speed: 5.6ms preprocess, 242.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 259.9ms
# Speed: 5.0ms preprocess, 259.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 260.0ms
# Speed: 4.0ms preprocess, 260.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 239.0ms
# Speed: 4.0ms preprocess, 239.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 233.0ms
# Speed: 3.0ms preprocess, 233.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 237.9ms
# Speed: 4.1ms preprocess, 237.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 236.0ms
# Speed: 3.0ms preprocess, 236.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 230.0ms
# Speed: 4.0ms preprocess, 230.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 242.4ms
# Speed: 3.6ms preprocess, 242.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 233.0ms
# Speed: 3.0ms preprocess, 233.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 236.0ms
# Speed: 4.0ms preprocess, 236.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 230.0ms
# Speed: 4.0ms preprocess, 230.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 238.1ms
# Speed: 3.0ms preprocess, 238.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 248.0ms
# Speed: 7.0ms preprocess, 248.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 240.9ms
# Speed: 5.1ms preprocess, 240.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 243.0ms
# Speed: 4.0ms preprocess, 243.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 234.0ms
# Speed: 4.0ms preprocess, 234.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 240.5ms
# Speed: 3.5ms preprocess, 240.5ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 243.0ms
# Speed: 3.0ms preprocess, 243.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 236.0ms
# Speed: 3.0ms preprocess, 236.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 198.0ms
# Speed: 4.0ms preprocess, 198.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 190.0ms
# Speed: 3.0ms preprocess, 190.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 190.0ms
# Speed: 3.0ms preprocess, 190.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 211.0ms
# Speed: 3.0ms preprocess, 211.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 202.6ms
# Speed: 3.0ms preprocess, 202.6ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 197.0ms
# Speed: 4.0ms preprocess, 197.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 203.9ms
# Speed: 4.0ms preprocess, 203.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 208.0ms
# Speed: 4.0ms preprocess, 208.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 203.5ms
# Speed: 3.0ms preprocess, 203.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 202.7ms
# Speed: 4.0ms preprocess, 202.7ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 200.0ms
# Speed: 4.0ms preprocess, 200.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 191.0ms
# Speed: 5.1ms preprocess, 191.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 196.2ms
# Speed: 4.0ms preprocess, 196.2ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 193.5ms
# Speed: 3.5ms preprocess, 193.5ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 205.0ms
# Speed: 7.0ms preprocess, 205.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 202.0ms
# Speed: 3.0ms preprocess, 202.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 205.0ms
# Speed: 4.0ms preprocess, 205.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 201.0ms
# Speed: 3.0ms preprocess, 201.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 202.0ms
# Speed: 3.0ms preprocess, 202.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 201.0ms
# Speed: 3.0ms preprocess, 201.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 196.0ms
# Speed: 3.0ms preprocess, 196.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 208.9ms
# Speed: 3.0ms preprocess, 208.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 205.0ms
# Speed: 3.0ms preprocess, 205.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 204.9ms
# Speed: 7.0ms preprocess, 204.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 201.0ms
# Speed: 3.0ms preprocess, 201.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 199.1ms
# Speed: 3.0ms preprocess, 199.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 194.1ms
# Speed: 4.0ms preprocess, 194.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 198.9ms
# Speed: 3.0ms preprocess, 198.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 199.0ms
# Speed: 3.0ms preprocess, 199.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 199.0ms
# Speed: 2.5ms preprocess, 199.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 198.0ms
# Speed: 3.0ms preprocess, 198.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 197.3ms
# Speed: 4.7ms preprocess, 197.3ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 230.0ms
# Speed: 4.0ms preprocess, 230.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 206.0ms
# Speed: 4.0ms preprocess, 206.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 211.0ms
# Speed: 3.0ms preprocess, 211.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 257.0ms
# Speed: 4.0ms preprocess, 257.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 236.1ms
# Speed: 4.0ms preprocess, 236.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 237.1ms
# Speed: 5.0ms preprocess, 237.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 228.0ms
# Speed: 4.0ms preprocess, 228.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 214.0ms
# Speed: 4.0ms preprocess, 214.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 218.0ms
# Speed: 3.0ms preprocess, 218.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 223.0ms
# Speed: 3.0ms preprocess, 223.0ms inference, 2.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 219.0ms
# Speed: 3.1ms preprocess, 219.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 213.0ms
# Speed: 3.0ms preprocess, 213.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 227.9ms
# Speed: 3.1ms preprocess, 227.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
# 3
#
# 0: 416x640 1 person, 212.4ms
# Speed: 7.0ms preprocess, 212.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 204.5ms
# Speed: 3.0ms preprocess, 204.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 218.4ms
# Speed: 3.0ms preprocess, 218.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 209.4ms
# Speed: 3.0ms preprocess, 209.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 196.5ms
# Speed: 3.0ms preprocess, 196.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 198.0ms
# Speed: 4.0ms preprocess, 198.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 202.5ms
# Speed: 3.0ms preprocess, 202.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 192.5ms
# Speed: 3.0ms preprocess, 192.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 200.6ms
# Speed: 3.0ms preprocess, 200.6ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 195.7ms
# Speed: 3.0ms preprocess, 195.7ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 230.0ms
# Speed: 3.0ms preprocess, 230.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 199.0ms
# Speed: 3.0ms preprocess, 199.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 192.0ms
# Speed: 3.0ms preprocess, 192.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 224.0ms
# Speed: 5.0ms preprocess, 224.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 198.0ms
# Speed: 3.0ms preprocess, 198.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 201.0ms
# Speed: 4.0ms preprocess, 201.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 200.0ms
# Speed: 4.0ms preprocess, 200.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 202.0ms
# Speed: 3.0ms preprocess, 202.0ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 211.0ms
# Speed: 6.0ms preprocess, 211.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 205.9ms
# Speed: 4.0ms preprocess, 205.9ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 213.9ms
# Speed: 3.0ms preprocess, 213.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 210.0ms
# Speed: 4.0ms preprocess, 210.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 202.1ms
# Speed: 3.0ms preprocess, 202.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 205.0ms
# Speed: 3.0ms preprocess, 205.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 219.0ms
# Speed: 6.0ms preprocess, 219.0ms inference, 3.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 205.1ms
# Speed: 4.0ms preprocess, 205.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 204.1ms
# Speed: 4.0ms preprocess, 204.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 201.8ms
# Speed: 3.0ms preprocess, 201.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 203.6ms
# Speed: 4.0ms preprocess, 203.6ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 210.6ms
# Speed: 4.0ms preprocess, 210.6ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 217.0ms
# Speed: 3.0ms preprocess, 217.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 213.0ms
# Speed: 4.0ms preprocess, 213.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 205.1ms
# Speed: 3.0ms preprocess, 205.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 206.4ms
# Speed: 3.0ms preprocess, 206.4ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 198.8ms
# Speed: 7.0ms preprocess, 198.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 200.0ms
# Speed: 3.5ms preprocess, 200.0ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 201.8ms
# Speed: 3.0ms preprocess, 201.8ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 205.9ms
# Speed: 5.1ms preprocess, 205.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 209.0ms
# Speed: 4.0ms preprocess, 209.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 206.1ms
# Speed: 4.0ms preprocess, 206.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 202.0ms
# Speed: 3.0ms preprocess, 202.0ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 203.0ms
# Speed: 4.0ms preprocess, 203.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 197.1ms
# Speed: 3.0ms preprocess, 197.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 208.2ms
# Speed: 3.0ms preprocess, 208.2ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 skateboard, 210.5ms
# Speed: 3.5ms preprocess, 210.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 skateboard, 244.0ms
# Speed: 3.0ms preprocess, 244.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 skateboard, 207.0ms
# Speed: 4.0ms preprocess, 207.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 skateboard, 203.9ms
# Speed: 3.0ms preprocess, 203.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 205.1ms
# Speed: 3.0ms preprocess, 205.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 199.1ms
# Speed: 4.0ms preprocess, 199.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 204.0ms
# Speed: 3.0ms preprocess, 204.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 201.0ms
# Speed: 3.0ms preprocess, 201.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 198.0ms
# Speed: 3.0ms preprocess, 198.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 200.9ms
# Speed: 4.0ms preprocess, 200.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 203.0ms
# Speed: 3.0ms preprocess, 203.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 204.0ms
# Speed: 2.9ms preprocess, 204.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 206.0ms
# Speed: 7.0ms preprocess, 206.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 197.0ms
# Speed: 4.0ms preprocess, 197.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 215.0ms
# Speed: 3.0ms preprocess, 215.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 222.0ms
# Speed: 5.0ms preprocess, 222.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 206.9ms
# Speed: 5.2ms preprocess, 206.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 205.0ms
# Speed: 5.0ms preprocess, 205.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 199.0ms
# Speed: 4.0ms preprocess, 199.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 205.0ms
# Speed: 4.0ms preprocess, 205.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 203.0ms
# Speed: 3.0ms preprocess, 203.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 199.0ms
# Speed: 4.0ms preprocess, 199.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 235.2ms
# Speed: 4.0ms preprocess, 235.2ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 202.0ms
# Speed: 3.0ms preprocess, 202.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 200.0ms
# Speed: 3.0ms preprocess, 200.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 202.7ms
# Speed: 4.0ms preprocess, 202.7ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# 4
#
# 0: 416x640 1 person, 223.4ms
# Speed: 6.0ms preprocess, 223.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 202.5ms
# Speed: 3.0ms preprocess, 202.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 197.5ms
# Speed: 3.0ms preprocess, 197.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 192.5ms
# Speed: 4.0ms preprocess, 192.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 200.5ms
# Speed: 3.0ms preprocess, 200.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 194.5ms
# Speed: 4.0ms preprocess, 194.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 197.5ms
# Speed: 4.0ms preprocess, 197.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 223.4ms
# Speed: 3.0ms preprocess, 223.4ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 199.4ms
# Speed: 4.0ms preprocess, 199.4ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 201.5ms
# Speed: 4.0ms preprocess, 201.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 194.5ms
# Speed: 3.0ms preprocess, 194.5ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 190.5ms
# Speed: 4.0ms preprocess, 190.5ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 194.9ms
# Speed: 3.0ms preprocess, 194.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 211.0ms
# Speed: 3.0ms preprocess, 211.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 200.9ms
# Speed: 4.0ms preprocess, 200.9ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 206.0ms
# Speed: 3.0ms preprocess, 206.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 201.0ms
# Speed: 3.0ms preprocess, 201.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 209.9ms
# Speed: 28.5ms preprocess, 209.9ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 202.1ms
# Speed: 5.0ms preprocess, 202.1ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 206.0ms
# Speed: 3.0ms preprocess, 206.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 203.0ms
# Speed: 3.0ms preprocess, 203.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 201.0ms
# Speed: 5.0ms preprocess, 201.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 206.9ms
# Speed: 4.1ms preprocess, 206.9ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 200.0ms
# Speed: 3.0ms preprocess, 200.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 201.0ms
# Speed: 4.0ms preprocess, 201.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 201.5ms
# Speed: 3.5ms preprocess, 201.5ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 199.0ms
# Speed: 3.0ms preprocess, 199.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 209.0ms
# Speed: 3.0ms preprocess, 209.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 skateboard, 213.0ms
# Speed: 3.0ms preprocess, 213.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 212.0ms
# Speed: 4.0ms preprocess, 212.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 216.0ms
# Speed: 3.0ms preprocess, 216.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 211.0ms
# Speed: 4.0ms preprocess, 211.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 200.0ms
# Speed: 4.0ms preprocess, 200.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 skateboard, 213.0ms
# Speed: 3.0ms preprocess, 213.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 1 skateboard, 199.0ms
# Speed: 3.0ms preprocess, 199.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 204.0ms
# Speed: 3.0ms preprocess, 204.0ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 205.0ms
# Speed: 4.1ms preprocess, 205.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 219.0ms
# Speed: 9.0ms preprocess, 219.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 198.0ms
# Speed: 3.0ms preprocess, 198.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 198.1ms
# Speed: 3.0ms preprocess, 198.1ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 210.0ms
# Speed: 3.0ms preprocess, 210.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 205.0ms
# Speed: 3.0ms preprocess, 205.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 207.1ms
# Speed: 3.0ms preprocess, 207.1ms inference, 3.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 210.0ms
# Speed: 5.0ms preprocess, 210.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 210.0ms
# Speed: 3.0ms preprocess, 210.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 202.0ms
# Speed: 5.0ms preprocess, 202.0ms inference, 1.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 209.0ms
# Speed: 3.0ms preprocess, 209.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 416x640 1 person, 196.0ms
# Speed: 3.0ms preprocess, 196.0ms inference, 2.0ms postprocess per image at shape (1, 3, 416, 640)
# Error loading video.
